# %%
'''
PROJECT A
TAN KAI EL
6/xx/24
Version 27 May 2024 V0
'''

# init

from datetime import datetime
import import_ipynb
import handler as hd

# %%
# main

def main_menu():
    print('''
╔════════════════════════════════════════════╗
║          Subject Management Menu           ║
╠════════════════════════════════════════════╣
║ 1.  Search subject with subject code       ║
║ 2.  Add new subject                        ║
║ 3.  Edit subject with subject code         ║
║ 4.  Delete subject                         ║
║ 7.  Display subjects                       ║
║ 8.  Load data                              ║
║ 9.  Save data                              ║
║ 0.  Exit                                   ║
╠════════════════════════════════════════════╣
║         made with love by kai el <3        ║
╚════════════════════════════════════════════╝
''')

# Dictionary to map user input to corresponding functions
menu_options = {
    "1": hd.search_subject,
    "2": hd.add_subject,
    "3": hd.edit_subject,
    "4": hd.delete_subject,
    "7": hd.display_subjects,
    "8": hd.load_data,
    "9": hd.save_data
}

running = True
while running:
    main_menu()
    choice = input("Enter option: ")
    if choice in menu_options:
        menu_options[choice]()
    elif choice == '0':
        hd.exit_program()
        running = False
    else:
        print("Invalid choice. Please enter a number corresponding to a menu option.")
# Out:
# ╔════════════════════════════════════════════╗
# ║          Subject Management Menu           ║
# ╠════════════════════════════════════════════╣
# ║ 1.  Search subject with subject code       ║
# ║ 2.  Add new subject                        ║
# ║ 3.  Edit subject with subject code         ║
# ║ 4.  Delete subject                         ║
# ║ 7.  Display subjects                       ║
# ║ 8.  Load data                              ║
# ║ 9.  Save data                              ║
# ║ 0.  Exit                                   ║
# ╠════════════════════════════════════════════╣
# ║         made with love by kai el <3        ║
# ╚════════════════════════════════════════════╝
#
# ╔════════════════════════════════════╗
# ║  Search subject with subject code  ║
# ╚════════════════════════════════════╝
# ╔════════════════════════════════╗
# ║  Code validated! Searching...  ║
# ╚════════════════════════════════╝
# ╔══════════════════════╗
# ║  Subject not found.  ║
# ...
